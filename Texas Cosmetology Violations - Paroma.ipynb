# %% [markdown]
# # Texas Cosmetologist Violations
#
# Texas has a system for [searching for license violations](https://www.tdlr.texas.gov/cimsfo/fosearch.asp). You're going to search for cosmetologists!

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# We'll be using Selenium for this, *not* BeautifulSoup and requests.

# %%
from selenium import webdriver
driver = webdriver.Chrome()

# %% [markdown]
# ## Starting your search
#
# Starting from [here](https://www.tdlr.texas.gov/cimsfo/fosearch.asp), search for **cosmetologist violations** for people with the last name **Nguyen**.

# %%
driver.get("https://www.tdlr.texas.gov/cimsfo/fosearch.asp")

# %%
textbox = driver.find_element_by_xpath("/html/body/div[1]/div/div[2]/div/div/section/div/div/table/tbody/tr/td/form/table/tbody/tr[7]/td/p/input")

# %%
textbox.send_keys("Nguyen")

# %%
driver.find_element_by_xpath("/html/body/div[1]/div/div[2]/div/div/section/div/div/table/tbody/tr/td/form/table/tbody/tr[18]/td/input[1]").click()

# %% [markdown]
# ## Scraping
#
# Once you are on the results page, do this.

# %% [markdown]
# ### Loop through each result and print the entire row
#
# Okay wait, that's a heck of a lot. Use `[:10]` to only do the first ten (`listname[:10]` gives you the first ten).

# %%
table = driver.find_elements_by_tag_name('tr')
for each in table[:10]:
    print (each.text)
# Out:
# Name and Location Order Basis for Order
# NGUYEN, MIMI PHAM
# City: KATY
# County: HARRIS
# Zip Code: 77449
#
#
# License #: 784210
#
# Complaint # COS20190010072 Date: 11/12/2020
#
# Respondent is assessed an administrative penalty in the amount of $1,125. Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.
# NGUYEN, HA
# City: ARLINGTON
# County: TARRANT
# Zip Code: 76017
#
#
# License #: 764888
#
# Complaint # COS20190016762 Date: 11/12/2020
#
# Respondent is assessed an administrative penalty in the amount of $2,250. Respondent failed to clean and sanitize four (4) whirlpool foot spas as required at the end of each day, constituting two (2) violations; Respondent failed to keep a record of the date and time of four (4) foot spas daily or bi-weekly cleaning and if the foot spas were not used, constituting two (2) violations.
# NGUYEN, THAO HONG
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78238
#
#
# License #(s): 799926, 1753491
#
# Complaint # COS20200010387 Date: 11/12/2020
#
# Respondent is assessed an administrative penalty in the amount of $575. Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# NGUYEN, CINDY
# City: CORPUS CHRISTI
# County: NUECES
# Zip Code: 78414
#
#
# License #(s): 806232, 1260359, 1280071
#
# Complaint # COS20200010502 Date: 10/29/2020
#
# Respondent is assessed an administrative penalty in the amount of $1,125. Respondent failed to clean and disinfect all wax pots; Respondent failed to properly clean multi-use items prior to each service.
# NGUYEN, CHAU KHANH LINH
# City: MONTGOMERY
# County: OUT OF STATE
# Zip Code: 36116
#
#
# License #: 1764073
#
# Complaint # COS20190008104 Date: 10/26/2020
#
# The Respondent's Cosmetology Manicurist license is revoked. Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.
# NGUYEN, TRANG T
# City: SEGUIN
# County: GUADALUPE
# Zip Code: 78155
#
#
# License #: 748483
#
# Complaint # COS20200010511 Date: 10/26/2020
#
# Respondent is assessed an administrative penalty in the amount of $935. Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to wipe clean and disinfect electrical equipment that cannot be immersed in the liquid prior to each use on a client.
# NGUYEN, DUNG MINH
# City: HOUSTON
# County: HARRIS
# Zip Code: 77066
#
#
# License #: 785878
#
# Complaint # COS20200004202 Date: 10/19/2020
#
# Respondent is assessed an administrative penalty in the amount of $1,250. Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to store eyelash extensions in a sealed bag or covered container and kept in a clean dry debris-free storage area; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# NGUYEN, YEN NHI THI
# City: AUSTIN
# County: TRAVIS
# Zip Code: 78717
#
#
# License #: 763645
#
# Complaint # COS20190004199 Date: 10/14/2020
#
# Respondent is assessed an administrative penalty in the amount of $675. Respondent failed to clean and disinfect all wax pots; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent stored chemicals in a restroom accessible to the public; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.
# NGUYEN, JOHNNY DAT
# City: MISSION
# County: HIDALGO
# Zip Code: 78574
#
#
# License #: 797651
#
# Complaint # COS20200000101 Date: 10/14/2020
#
# Respondent is assessed an administrative penalty in the amount of $1,500. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day - two violations.

# %% [markdown]
# ### Loop through each result and print each person's name
#
# You'll get an error because the first one doesn't have a name. How do you make that not happen?! If you want to ignore an error, you use code like this:
#
# ```python
# try:
#    # try to do something
# except:
#    # Instead of stopping on an error, it'll jump down here instead
#    print("It didn't work')
# ```
#
# It should help you out. If you don't want to print anything, you can type `pass` instead of the `print` statement. Most people use `pass`, but it's also nice to print out debug statements so you know when/where it's running into errors.
#
# **Why doesn't the first one have a name?**

# %%
for each in table[:10]:
    try:
        name = each.find_elements_by_class_name('results_text')
        print (name[0].text)
    except:
        print ("not working")
# Out:
# not working
# NGUYEN, MIMI PHAM
# NGUYEN, HA
# NGUYEN, THAO HONG
# NGUYEN, CINDY
# NGUYEN, CHAU KHANH LINH
# NGUYEN, TRANG T
# NGUYEN, DUNG MINH
# NGUYEN, YEN NHI THI
# NGUYEN, JOHNNY DAT

# %% [markdown]
# ## Loop through each result, printing each violation description ("Basis for order")
#
# > - *Tip: You'll get an error even if you're ALMOST right - which row is causing the problem?*
# > - *Tip: You can get the HTML of something by doing `.get_attribute('innerHTML')` - it might help you diagnose your issue.*
# > - *Tip: Or I guess you could just skip the one with the problem...*

# %%
for each in table[:10]:
    try:
        description = each.find_elements_by_tag_name('td')
        print (description[2].text)
        print ("------")
    except:
        print ("not working")
# Out:
# not working
# Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.
# ------
# Respondent failed to clean and sanitize four (4) whirlpool foot spas as required at the end of each day, constituting two (2) violations; Respondent failed to keep a record of the date and time of four (4) foot spas daily or bi-weekly cleaning and if the foot spas were not used, constituting two (2) violations.
# ------
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# ------
# Respondent failed to clean and disinfect all wax pots; Respondent failed to properly clean multi-use items prior to each service.
# ------
# Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.
# ------
# Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to wipe clean and disinfect electrical equipment that cannot be immersed in the liquid prior to each use on a client.
# ------
# Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to store eyelash extensions in a sealed bag or covered container and kept in a clean dry debris-free storage area; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# ------
# Respondent failed to clean and disinfect all wax pots; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent stored chemicals in a restroom accessible to the public; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.
# ------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day - two violations.
# ------

# %% [markdown]
# ## Loop through each result, printing the complaint number
#
# - TIP: Think about the order of the elements

# %%
for each in table[:10]:
    try:
        comp = each.find_elements_by_class_name('results_text')
        print (f'Complaint number: {comp[5].text}')
        print ("------")
    except:
        print ("not working")
# Out:
# not working
# Complaint number: COS20190010072
# ------
# Complaint number: COS20190016762
# ------
# Complaint number: COS20200010387
# ------
# Complaint number: COS20200010502
# ------
# Complaint number: COS20190008104
# ------
# Complaint number: COS20200010511
# ------
# Complaint number: COS20200004202
# ------
# Complaint number: COS20190004199
# ------
# Complaint number: COS20200000101
# ------

# %% [markdown]
# ## Saving the results
#
# ### Loop through each result to create a list of dictionaries
#
# Each dictionary must contain
#
# - Person's name
# - Violation description
# - Violation number
# - License Numbers
# - Zip Code
# - County
# - City
#
# Create a new dictionary for each result (except the header).
#
# > *Tip: If you want to ask for the "next sibling," you can't use `find_next_sibling` in Selenium, you need to use `element.find_element_by_xpath("following-sibling::div")` to find the next div, or `element.find_element_by_xpath("following-sibling::*")` to find the next anything.

# %%
# for each in table[1:10]:
#     #try:
#     info = each.find_elements_by_class_name('results_text')
#     compno = info[5].text
#     licenseno = info[4].text
#     zipcode = info[3].text
#     county = info[2].text
#     city = info[1].text
#     print (city, county, zipcode, licenseno, compno)

# %%
eachdict = []
for each in table:
    try:
        name = each.find_elements_by_class_name('results_text')
        description = each.find_elements_by_tag_name('td')
        info = each.find_elements_by_class_name('results_text')
        eachdict.append({'name': name[0].text, 
                         'description': description[2].text, 
                         'complaint number': info[5].text,
                        'license number': info[4].text,
                        'city': info[1].text,
                        'county': info[2].text,
                        'zip code':info[3].text
                        })
    except:
        pass
    
eachdict
# Out:
# [{'name': 'NGUYEN, MIMI PHAM',
#   'description': 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.',
#   'complaint number': 'COS20190010072',
#   'license number': '784210',
#   'city': 'KATY',
#   'county': 'HARRIS',
#   'zip code': '77449'},
#  {'name': 'NGUYEN, HA',
#   'description': 'Respondent failed to clean and sanitize four (4) whirlpool foot spas as required at the end of each day, constituting two (2) violations; Respondent failed to keep a record of the date and time of four (4) foot spas daily or bi-weekly cleaning and if the foot spas were not used, constituting two (2) violations.',
#   'complaint number': 'COS20190016762',
#   'license number': '764888',
#   'city': 'ARLINGTON',
#   'county': 'TARRANT',
#   'zip code': '76017'},
#  {'name': 'NGUYEN, THAO HONG',
#   'description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'complaint number': 'COS20200010387',
#   'license number': '799926, 1753491',
#   'city': 'SAN ANTONIO',
#   'county': 'BEXAR',
#   'zip code': '78238'},
#  {'name': 'NGUYEN, CINDY',
#   'description': 'Respondent failed to clean and disinfect all wax pots; Respondent failed to properly clean multi-use items prior to each service.',
#   'complaint number': 'COS20200010502',
#   'license number': '806232, 1260359, 1280071',
#   'city': 'CORPUS CHRISTI',
#   'county': 'NUECES',
#   'zip code': '78414'},
#  {'name': 'NGUYEN, CHAU KHANH LINH',
#   'description': 'Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.',
#   'complaint number': 'COS20190008104',
#   'license number': '1764073',
#   'city': 'MONTGOMERY',
#   'county': 'OUT OF STATE',
#   'zip code': '36116'},
#  {'name': 'NGUYEN, TRANG T',
#   'description': 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to wipe clean and disinfect electrical equipment that cannot be immersed in the liquid prior to each use on a client.',
#   'complaint number': 'COS20200010511',
#   'license number': '748483',
#   'city': 'SEGUIN',
#   'county': 'GUADALUPE',
#   'zip code': '78155'},
#  {'name': 'NGUYEN, DUNG MINH',
#   'description': 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to store eyelash extensions in a sealed bag or covered container and kept in a clean dry debris-free storage area; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'complaint number': 'COS20200004202',
#   'license number': '785878',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip code': '77066'},
#  {'name': 'NGUYEN, YEN NHI THI',
#   'description': 'Respondent failed to clean and disinfect all wax pots; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent stored chemicals in a restroom accessible to the public; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.',
#   'complaint number': 'COS20190004199',
#   'license number': '763645',
#   'city': 'AUSTIN',
#   'county': 'TRAVIS',
#   'zip code': '78717'},
#  {'name': 'NGUYEN, JOHNNY DAT',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day - two violations.',
#   'complaint number': 'COS20200000101',
#   'license number': '797651',
#   'city': 'MISSION',
#   'county': 'HIDALGO',
#   'zip code': '78574'},
#  {'name': 'NGUYEN, KELLY PHUONG N',
#   'description': 'Respondent failed properly clean and sanitize the metal implements used at the Salon.',
#   'complaint number': 'COS20200011664',
#   'license number': '751553',
#   'city': 'CORPUS CHRISTI',
#   'county': 'NUECES',
#   'zip code': '78413'},
#  {'name': 'NGUYEN, NGA THU',
#   'description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection.',
#   'complaint number': 'COS20200010961',
#   'license number': '737176',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip code': '77038'},
#  {'name': 'NGUYEN, IVY',
#   'description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly; Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.',
#   'complaint number': 'COS20200008858',
#   'license number': '772886',
#   'city': 'SHERMAN',
#   'county': 'GRAYSON',
#   'zip code': '75092'},
#  {'name': 'NGUYEN, NHO HONG THI',
#   'description': 'Respondent operated a massage establishment without a massage establishment license.',
#   'complaint number': 'MAS20190005842',
#   'license number': 'Not Licensed',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip code': '77061'},
#  {'name': 'NGUYEN, TAMMY',
#   'description': 'Respondent allowed an employee to engage in sexual contact in the massage establishment',
#   'complaint number': 'MAS20190013644',
#   'license number': 'Not Licensed',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip code': '77036'},
#  {'name': 'NGUYEN, DIEMTRINH T',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'complaint number': 'COS20200008859',
#   'license number': '736591',
#   'city': 'CARROLLTON',
#   'county': 'DALLAS',
#   'zip code': '75010'},
#  {'name': 'NGUYEN, HUAN CAO',
#   'description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; After each client, the following implements shall be cleaned, disinfected and sterilized or sanitized in accordance with the rule: metal pusher and files, cuticle nipper and scissors, metal tweezers, finger and toe-nail clippers, and electric drill bits.',
#   'complaint number': 'COS20200009732',
#   'license number': '786237',
#   'city': 'SAN ANTONIO',
#   'county': 'BEXAR',
#   'zip code': '78229'},
#  {'name': 'NGUYEN, THOA KIM',
#   'description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.',
#   'complaint number': 'COS20200006548',
#   'license number': '758361',
#   'city': 'CORPUS CHRISTI',
#   'county': 'NUECES',
#   'zip code': '78413'},
#  {'name': 'NGUYEN, TONY',
#   'description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'complaint number': 'COS20200009605',
#   'license number': 'Not Licensed',
#   'city': 'MARBLE FALLS',
#   'county': 'BURNET',
#   'zip code': '78654'},
#  {'name': 'NGUYEN, TAMMY',
#   'description': 'Respondent operated a massage establishment without a massage establishment license.',
#   'complaint number': 'MAS20190013644',
#   'license number': 'Not Licensed',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip code': '77036'},
#  {'name': 'NGUYEN, HIEN',
#   'description': 'Respondent failed to clean and disinfect all wax pots.',
#   'complaint number': 'COS20190016479',
#   'license number': '801727',
#   'city': 'LONGVIEW',
#   'county': 'GREGG',
#   'zip code': '75605'},
#  {'name': 'NGUYEN, NGOC TRAM',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20190012148',
#   'license number': '712767',
#   'city': 'FORT WORTH',
#   'county': 'TARRANT',
#   'zip code': '76137'},
#  {'name': 'NGUYEN, TRAN NAM',
#   'description': 'Respondent failed to cooperate with the inspector in the performance of an inspection.',
#   'complaint number': 'COS20190010318',
#   'license number': '733729',
#   'city': 'CANYON',
#   'county': 'RANDALL',
#   'zip code': '79015'},
#  {'name': 'NGUYEN, PHILLIP',
#   'description': 'Respondent failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone; Respondent failed to sweep up and deposit hair cuttings in a closed receptacle after each hair cut. Respondent failed to thoroughly clean the floors each day.',
#   'complaint number': 'COS20190014688',
#   'license number': '692372',
#   'city': 'EL PASO',
#   'county': 'EL PASO',
#   'zip code': '79912'},
#  {'name': 'NGUYEN, THUY T',
#   'description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed properly clean and sanitize the metal implements used at the Salon.',
#   'complaint number': 'COS20190004016',
#   'license number': '794091',
#   'city': 'CARROLLTON',
#   'county': 'DALLAS',
#   'zip code': '75007'},
#  {'name': 'NGUYEN, TRACY',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'complaint number': 'COS20190016499',
#   'license number': '746762',
#   'city': 'FORT WORTH',
#   'county': 'TARRANT',
#   'zip code': '76137'},
#  {'name': 'NGUYEN, LE PHUC',
#   'description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20200006146',
#   'license number': '739879',
#   'city': 'SACHSE',
#   'county': 'COLLIN',
#   'zip code': '75048'},
#  {'name': 'NGUYEN, HAI MINH',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'complaint number': 'COS20190016549',
#   'license number': '726039, 1110890',
#   'city': 'EL PASO',
#   'county': 'EL PASO',
#   'zip code': '79936'},
#  {'name': 'NGUYEN, TUYET',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20190017217',
#   'license number': '774330, 1658860',
#   'city': 'GRAND PRAIRIE',
#   'county': 'DALLAS',
#   'zip code': '75052'},
#  {'name': 'NGUYEN, VICKI',
#   'description': 'Respondent was placed on deferred adjudication for the offense of prostitution and is not eligible for a license.',
#   'complaint number': 'MAS20190004778',
#   'license number': 'MT102379',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip code': '77024'},
#  {'name': 'NGUYEN, BA VAN',
#   'description': 'Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets.',
#   'complaint number': 'COS20190016854',
#   'license number': '676940',
#   'city': 'ARLINGTON',
#   'county': 'TARRANT',
#   'zip code': '76001'},
#  {'name': 'NGUYEN, LAN THANH',
#   'description': 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.',
#   'complaint number': 'COS20190017175',
#   'license number': '766697',
#   'city': 'DALLAS',
#   'county': 'DALLAS',
#   'zip code': '75216'},
#  {'name': 'NGUYEN, PHUOC BA',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20190013017',
#   'license number': '788725, 1552617',
#   'city': 'SAN ANTONIO',
#   'county': 'BEXAR',
#   'zip code': '78250'},
#  {'name': 'NGUYEN, LINH THUY KIEU',
#   'description': 'Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets.',
#   'complaint number': 'COS20190016161',
#   'license number': '795480, 1700076',
#   'city': 'GARLAND',
#   'county': 'DALLAS',
#   'zip code': '75044'},
#  {'name': 'NGUYEN, TONY MINH',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20200000652',
#   'license number': '791638, 1124706',
#   'city': 'MARBLE FALLS',
#   'county': 'BURNET',
#   'zip code': '78654'},
#  {'name': 'NGUYEN, THANH',
#   'description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'complaint number': 'COS20190007906',
#   'license number': '790672',
#   'city': 'FRISCO',
#   'county': 'COLLIN',
#   'zip code': '75034'},
#  {'name': 'NGUYEN, HIEN THI MINH',
#   'description': 'Respondent failed to maintain cleaning records for whirlpool foot spas; Respondent failed to utilize the sterilizer in the salon for the purpose of sterilizing metal implements; Respondent failed to store cosmetology items in a clean and debris free environment; Respondent stored chemical supplies in the restroom.',
#   'complaint number': 'COS20190003737',
#   'license number': '795179',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip code': '77083'},
#  {'name': 'NGUYEN, VAN NGOC THAO',
#   'description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean, disinfect, and sterilize all multi-use implements prior to each use.',
#   'complaint number': 'COS20190006118',
#   'license number': 'Not Licensed',
#   'city': 'WAXAHACHIE',
#   'county': 'ELLIS',
#   'zip code': '75165'},
#  {'name': 'NGUYEN, TAM THANH',
#   'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'complaint number': 'COS20200002642',
#   'license number': '1163702',
#   'city': 'SAN ANGELO',
#   'county': 'TOM GREEN',
#   'zip code': '76904'},
#  {'name': 'NGUYEN, ANDY HUU',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.',
#   'complaint number': 'COS20190009211',
#   'license number': '776906, 1189873',
#   'city': 'HURST',
#   'county': 'TARRANT',
#   'zip code': '76053'},
#  {'name': 'NGUYEN, CUONG HULL',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20190010611',
#   'license number': '767705, 1094245',
#   'city': 'GRAND PRAIRIE',
#   'county': 'TARRANT',
#   'zip code': '75052'},
#  {'name': 'NGUYEN, NANCY HOA',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent possessed an electric drill other than those specifically designed and manufactured for use in the professional nail industry.',
#   'complaint number': 'COS20190010665',
#   'license number': '785647, 1121812',
#   'city': 'GARLAND',
#   'county': 'DALLAS',
#   'zip code': '75044'},
#  {'name': 'NGUYEN, THOA THI KIM',
#   'description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.',
#   'complaint number': 'COS20190001932',
#   'license number': '739510',
#   'city': 'CORPUS CHRISTI',
#   'county': 'NUECES',
#   'zip code': '78411'},
#  {'name': 'NGUYEN, TRANG',
#   'description': 'Respondent possessed or used a prohibited implement, specifically a blade or cutting tool intended for the purpose of removing corns or calluses.',
#   'complaint number': 'COS20190014576',
#   'license number': '693311',
#   'city': 'GARLAND',
#   'county': 'DALLAS',
#   'zip code': '75041'},
#  {'name': 'NGUYEN, THONG VAN',
#   'description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'complaint number': 'COS20190001897',
#   'license number': '750663',
#   'city': 'EL PASO',
#   'county': 'EL PASO',
#   'zip code': '79912'},
#  {'name': 'NGUYEN, TUAN',
#   'description': "Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to disinfect the salon's whirlpool foot spa basins with an EPA-registered disinfectant.",
#   'complaint number': 'COS20190009239',
#   'license number': '783281',
#   'city': 'DALLAS',
#   'county': 'DALLAS',
#   'zip code': '75237'},
#  {'name': 'NGUYEN, LYNDA',
#   'description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to dispose of single use items after each use.',
#   'complaint number': 'COS20190009484',
#   'license number': '781789',
#   'city': 'KATY',
#   'county': 'HARRIS',
#   'zip code': '77449'},
#  {'name': 'NGUYEN, CATHY H',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'ROUND ROCK',
#   'license number': 'NGUYEN, JOHNNY VAN',
#   'city': 'ROUND ROCK',
#   'county': 'WILLIAMSON',
#   'zip code': '78665'},
#  {'name': 'NGUYEN, PAMELA DAN',
#   'description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to make records, on a department-approved form with the date and time the salon discarded the liners for each whirlpool foot spas.',
#   'complaint number': 'COS20190011923',
#   'license number': '747589',
#   'city': 'SEGUIN',
#   'county': 'GUADALUPE',
#   'zip code': '78155'},
#  {'name': 'NGUYEN, SON QUOC',
#   'description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'complaint number': 'COS20190005539',
#   'license number': '772305, 1240974',
#   'city': 'HILLSBORO',
#   'county': 'HILL',
#   'zip code': '76645'},
#  {'name': 'NGUYEN, KIM',
#   'description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'complaint number': 'COS20190010176',
#   'license number': '786602',
#   'city': 'DALLAS',
#   'county': 'DALLAS',
#   'zip code': '75240'},
#  {'name': 'NGUYEN, THAI VAN',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to dispose of single use items after each use; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'complaint number': 'COS20190010397',
#   'license number': '797287, 1187211',
#   'city': 'GARLAND',
#   'county': 'DALLAS',
#   'zip code': '75040'},
#  {'name': 'NGUYEN, HANH THI',
#   'description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.',
#   'complaint number': 'COS20190011044',
#   'license number': '786707',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip code': '77049'},
#  {'name': 'NGUYEN, DIEP THI NGOC',
#   'description': 'Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.',
#   'complaint number': 'COS20190003373',
#   'license number': '760528',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip code': '77067'},
#  {'name': 'NGUYEN, CASEY',
#   'description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'complaint number': 'COS20190010299',
#   'license number': '790137',
#   'city': 'CYPRESS',
#   'county': 'HARRIS',
#   'zip code': '77429'},
#  {'name': 'NGUYEN, ANTHONY VAN',
#   'description': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.",
#   'complaint number': 'COS20190013988',
#   'license number': '750159',
#   'city': 'HALTOM CITY',
#   'county': 'TARRANT',
#   'zip code': '76117'},
#  {'name': 'NGUYEN, CHRISTINA D',
#   'description': 'Respondent failed to dispose of single use items after each use; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20190012652',
#   'license number': '716740',
#   'city': 'PORT ARTHUR',
#   'county': 'JEFFERSON',
#   'zip code': '77642'},
#  {'name': 'NGUYEN, PHUONG T',
#   'description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.',
#   'complaint number': 'COS20180015395',
#   'license number': '748459',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip code': '77083'},
#  {'name': 'NGUYEN, KENNY',
#   'description': 'Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'complaint number': 'COS20190010057',
#   'license number': '75611',
#   'city': 'DALLAS',
#   'county': 'DALLAS',
#   'zip code': '75232'},
#  {'name': 'NGUYEN, THAO (MINH THAO',
#   'description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'complaint number': 'COS20190010254',
#   'license number': '785264',
#   'city': 'LOCKHART',
#   'county': 'CALDWELL',
#   'zip code': '78644'},
#  {'name': 'NGUYEN, KENNY',
#   'description': 'Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'complaint number': 'COS20190000183',
#   'license number': '756711',
#   'city': 'DALLAS',
#   'county': 'DALLAS',
#   'zip code': '75232'},
#  {'name': 'NGUYEN, BA VAN',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20190010606',
#   'license number': '720112',
#   'city': 'MANSFIELD',
#   'county': 'TARRANT',
#   'zip code': '76063'},
#  {'name': 'NGUYEN, KHUYEN THI',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20190010961',
#   'license number': '771681, 1442799',
#   'city': 'HALTOM CITY',
#   'county': 'TARRANT',
#   'zip code': '76117'},
#  {'name': 'NGUYEN, SON DANG',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20190010635',
#   'license number': '720091, 1195752',
#   'city': 'FOREST HILL',
#   'county': 'TARRANT',
#   'zip code': '76119'},
#  {'name': 'NGUYEN, TUYEN THANH',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.',
#   'complaint number': 'COS20190014566',
#   'license number': '792178, 1468619, 1410422',
#   'city': 'AUBREY',
#   'county': 'DENTON',
#   'zip code': '76227'},
#  {'name': 'NGUYEN, STEVEN THAI',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20190010869',
#   'license number': '779635',
#   'city': 'CARROLLTON',
#   'county': 'DALLAS',
#   'zip code': '75007'},
#  {'name': 'NGUYEN, CY VAN',
#   'description': 'Respondent operated a cosmetology salon without the appropriate license.',
#   'complaint number': 'COS20190007921',
#   'license number': '765590',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip code': '77007'},
#  {'name': 'NGUYEN, QUANG DUC',
#   'description': 'Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent stored chemicals in a restroom accessible to the public.',
#   'complaint number': 'COS20180009800',
#   'license number': '749600, 1225146',
#   'city': 'LUBBOCK',
#   'county': 'LUBBOCK',
#   'zip code': '79424'},
#  {'name': 'NGUYEN, OANH THI',
#   'description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required when using portable whirlpool jets; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'complaint number': 'COS20180011968',
#   'license number': '770502',
#   'city': 'LIVINGSTON',
#   'county': 'POLK',
#   'zip code': '77351'},
#  {'name': 'NGUYEN, AN QUY',
#   'description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.',
#   'complaint number': 'COS20180014900',
#   'license number': '751433, 1083641',
#   'city': 'SAN ANTONIO',
#   'county': 'BEXAR',
#   'zip code': '78249'},
#  {'name': 'NGUYEN, HAU PHUC',
#   'description': 'Respondent was in possession of bottles containing methyl methacrylate monomer.',
#   'complaint number': 'COS20190008675',
#   'license number': '744770',
#   'city': 'CORPUS CHRISTI',
#   'county': 'NUECES',
#   'zip code': '78414'},
#  {'name': 'NGUYEN, KIM LIEN THI',
#   'description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'complaint number': 'COS20190009912',
#   'license number': '713587',
#   'city': 'AMARILLO',
#   'county': 'POTTER',
#   'zip code': '79107'},
#  {'name': 'NGUYEN, KENNY KHANH',
#   'description': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.",
#   'complaint number': 'COS20190011097',
#   'license number': '745308, 1419838',
#   'city': 'LEANDER',
#   'county': 'WILLIAMSON',
#   'zip code': '78641'},
#  {'name': 'NGUYEN, KIM LAN THI',
#   'description': "Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used constitutes two violations; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.",
#   'complaint number': 'SAN ANGELO',
#   'license number': 'NGUYEN, THUY TRANG T',
#   'city': 'SAN ANGELO',
#   'county': 'TOM GREEN',
#   'zip code': '76901'},
#  {'name': 'NGUYEN, DUONG VAN',
#   'description': 'Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product. Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.',
#   'complaint number': 'COS20180012023',
#   'license number': '748281',
#   'city': 'CORSICANA',
#   'county': 'NAVARRO',
#   'zip code': '75110'},
#  {'name': 'NGUYEN, HIEU CHAU',
#   'description': 'On two (2) occasions, Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day. Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'complaint number': 'COS20190008542',
#   'license number': '777856',
#   'city': 'EL PASO',
#   'county': 'EL PASO',
#   'zip code': '79938'},
#  {'name': 'NGUYEN, TRANG KIM',
#   'description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20190009430',
#   'license number': '773798',
#   'city': 'NEW CANEY',
#   'county': 'MONTGOMERY',
#   'zip code': '77357'},
#  {'name': 'NGUYEN, LINH H',
#   'description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'complaint number': 'COS20190009953',
#   'license number': '78841, 1520821',
#   'city': 'CONVERSE',
#   'county': 'BEXAR',
#   'zip code': '78109'},
#  {'name': 'NGUYEN, PHUONG DUC',
#   'description': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the manufacturer's instructions; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.",
#   'complaint number': 'COS20190010248',
#   'license number': '746023, 1244227, 1549650',
#   'city': 'PECOS',
#   'county': 'REEVES',
#   'zip code': '79772'},
#  {'name': 'NGUYEN, NGUYET M',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20190008693',
#   'license number': '724763, 1327682, 1148025',
#   'city': 'FORT WORTH',
#   'county': 'TARRANT',
#   'zip code': '76116'},
#  {'name': 'NGUYEN, VAN DO THI',
#   'description': 'Respondent performed or attempted to perform a practice of cosmetology with an expired license. Respondent operated a cosmetology salon without the appropriate license.',
#   'complaint number': 'COS20180016583',
#   'license number': '749933, 1695846',
#   'city': 'ALLEN',
#   'county': 'COLLIN',
#   'zip code': '75002'},
#  {'name': 'NGUYEN, XUAN THI',
#   'description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'complaint number': 'COS20190001467',
#   'license number': '765777',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip code': '77066'},
#  {'name': 'NGUYEN, MICHAEL TAN',
#   'description': 'Respondent possessed an electric drill other than those specifically designed and manufactured for use in the professional nail industry.',
#   'complaint number': 'COS20190008543',
#   'license number': '751319, 1654218',
#   'city': 'ROCKPORT',
#   'county': 'ARANSAS',
#   'zip code': '78382'},
#  {'name': 'NGUYEN, LANCHI',
#   'description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'complaint number': 'COS20190005139',
#   'license number': 'Not Licensed',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip code': '77015'},
#  {'name': 'NGUYEN, DIEM',
#   'description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.',
#   'complaint number': 'COS20190010629',
#   'license number': '688282',
#   'city': 'RICHARDSON',
#   'county': 'DALLAS',
#   'zip code': '75080'},
#  {'name': 'NGUYEN, LINH K',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20190010964',
#   'license number': '678261, 871430',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip code': '77072'},
#  {'name': 'NGUYEN, THOANG THI',
#   'description': 'Respondent employed a person as an operator who did not hold a license.',
#   'complaint number': 'COS20190011791',
#   'license number': '775443',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip code': '77075'},
#  {'name': 'NGUYEN, HOAI THU T',
#   'description': "Respondent failed to dispose of after each use all products and single use items that has been in contact with a client's skin.",
#   'complaint number': 'COS20190012199',
#   'license number': '735244',
#   'city': 'EL PASO',
#   'county': 'EL PASO',
#   'zip code': '79925'},
#  {'name': 'NGUYEN, JIMMY DUC',
#   'description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required daily, bi-weekly, and before use by each patron.',
#   'complaint number': 'GRAND PRAIRIE',
#   'license number': 'NGUYEN, MONG',
#   'city': 'GRAPEVINE',
#   'county': 'TARRANT',
#   'zip code': '76051'},
#  {'name': 'NGUYEN, NINH VAN',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20190003941',
#   'license number': '666588',
#   'city': 'GRAND PRAIRIE',
#   'county': 'TARRANT',
#   'zip code': '75052'},
#  {'name': 'NGUYEN, THANH HUU',
#   'description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect all wax pots.',
#   'complaint number': 'COS20180004399',
#   'license number': '745484, 1259159',
#   'city': 'RICHARDSON',
#   'county': 'DALLAS',
#   'zip code': '75081'},
#  {'name': 'NGUYEN, UYEN THI TU',
#   'description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'complaint number': 'COS20190001089',
#   'license number': 'Not Licensed',
#   'city': 'LUFKIN',
#   'county': 'ANGELINA',
#   'zip code': '75904'},
#  {'name': 'NGUYEN, BANH THI',
#   'description': 'Respondent performed barbering without the required license.',
#   'complaint number': 'COS20190007449',
#   'license number': 'Not Licensed',
#   'city': 'TEXARKANA',
#   'county': 'OUT OF STATE',
#   'zip code': '71854'},
#  {'name': 'NGUYEN, KHIET THANH',
#   'description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.',
#   'complaint number': 'COS20190002450',
#   'license number': '710894',
#   'city': 'CORPUS CHRISTI',
#   'county': 'NUECES',
#   'zip code': '78413'},
#  {'name': 'NGUYEN, SAM DUC',
#   'description': 'Respondent failed to dispose of single use items after each use; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'complaint number': 'COS20190005537',
#   'license number': '772341, 1596452',
#   'city': 'DEL RIO',
#   'county': 'VAL VERDE',
#   'zip code': '78840'},
#  {'name': 'NGUYEN, ALENA',
#   'description': 'Respondent used the word "massage" in an advertisement without being licensed as a massage establishment.',
#   'complaint number': 'MAS20180010778',
#   'license number': 'Not Licensed',
#   'city': 'SUGAR LAND',
#   'county': 'FORT BEND',
#   'zip code': '77498'},
#  {'name': 'NGUYEN, ANH HUU',
#   'description': 'Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer; Respondent failed to clean and disinfect all wax pots.',
#   'complaint number': 'PLANO',
#   'license number': 'NGUYEN, YEN HONG',
#   'city': 'PLANO',
#   'county': 'COLLIN',
#   'zip code': '75094'},
#  {'name': 'NGUYEN, DIANE N',
#   'description': 'Respondent failed to dispose of single use items after each use; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer.',
#   'complaint number': 'COS20190001468',
#   'license number': '681377, 1135046',
#   'city': 'SAN ANGELO',
#   'county': 'TOM GREEN',
#   'zip code': '76904'},
#  {'name': 'NGUYEN, MICHAEL',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20190003325',
#   'license number': '737006, 1155545',
#   'city': 'ARLINGTON',
#   'county': 'TARRANT',
#   'zip code': '76014'},
#  {'name': 'NGUYEN, CUONG TRAN',
#   'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'complaint number': 'COS20190006667',
#   'license number': '1594001',
#   'city': 'FORT WORTH',
#   'county': 'TARRANT',
#   'zip code': '76137'},
#  {'name': 'NGUYEN, TRAN NAM',
#   'description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'complaint number': 'COS20190005115',
#   'license number': '690490, 1143200',
#   'city': 'CANYON',
#   'county': 'RANDALL',
#   'zip code': '79015'},
#  {'name': 'NGUYEN, TAMMY',
#   'description': 'Respondent failed to cooperate with the inspector in the performance of an inspection.',
#   'complaint number': 'COS20180011336',
#   'license number': '781568, 1712086, 1234366, 1487516',
#   'city': 'ABILENE',
#   'county': 'TAYLOR',
#   'zip code': '79606'},
#  {'name': 'NGUYEN, SUONG THI TRUC',
#   'description': 'Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.',
#   'complaint number': 'COS20180002297',
#   'license number': '1695256',
#   'city': 'SACHSE',
#   'county': 'COLLIN',
#   'zip code': '74048'},
#  {'name': 'NGUYEN, THE THI',
#   'description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'complaint number': 'COS20180015927',
#   'license number': '728111, 1097604, 1437455',
#   'city': 'LEVELLAND',
#   'county': 'HOCKLEY',
#   'zip code': '79336'},
#  {'name': 'NGUYEN, KIMBERLY',
#   'description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'complaint number': 'COS20190000507',
#   'license number': '785284, 1516790',
#   'city': 'LONGVIEW',
#   'county': 'GREGG',
#   'zip code': '75604'},
#  {'name': 'NGUYEN, DUY KINH',
#   'description': 'Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.',
#   'complaint number': 'COS20190001290',
#   'license number': '765758, 1594533',
#   'city': 'CEDAR PARK',
#   'county': 'WILLIAMSON',
#   'zip code': '78613'},
#  {'name': 'NGUYEN, LEENA L',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20190002573',
#   'license number': '793631',
#   'city': 'EL PASO',
#   'county': 'EL PASO',
#   'zip code': '79924'},
#  {'name': 'NGUYEN, MAI TRANG',
#   'description': 'Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'complaint number': 'COS20190003107',
#   'license number': '792260, 1749538',
#   'city': 'THE COLONY',
#   'county': 'DENTON',
#   'zip code': '75056'},
#  {'name': 'NGUYEN, HUYEN T',
#   'description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'complaint number': 'COS20190005137',
#   'license number': '774449, 1152042',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip code': '77015'},
#  {'name': 'NGUYEN, TUNG T',
#   'description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'complaint number': 'COS20190005193',
#   'license number': '785431, 1667712',
#   'city': 'TYLER',
#   'county': 'SMITH',
#   'zip code': '75703'},
#  {'name': 'NGUYEN, HIEN XUAN T',
#   'description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20190002166',
#   'license number': '741087',
#   'city': 'SAN ANTONIO',
#   'county': 'BEXAR',
#   'zip code': '78248'},
#  {'name': 'NGUYEN, TUYET',
#   'description': 'Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.',
#   'complaint number': 'COS20170022240',
#   'license number': '774330',
#   'city': 'GRAND PRAIRIE',
#   'county': 'DALLAS',
#   'zip code': '75052'},
#  {'name': 'NGUYEN, HUYEN THI-MINH',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20170016527',
#   'license number': '732356, 1440217, 1529693',
#   'city': 'AUSTIN',
#   'county': 'TRAVIS',
#   'zip code': '78727'},
#  {'name': 'NGUYEN, HOA VAN',
#   'description': "Respondent submitted a renewal application that made false statements regarding the Respondent's criminal history; Respondent has been convicted of an offense that directly relates to the duties and responsibilities of the licensed occupation.",
#   'complaint number': 'COS20180003923',
#   'license number': '1216926',
#   'city': 'AUSTIN',
#   'county': 'TRAVIS',
#   'zip code': '78753'},
#  {'name': 'NGUYEN, PAUL',
#   'description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.',
#   'complaint number': 'COS20180016608',
#   'license number': '774054',
#   'city': 'MCKINNEY',
#   'county': 'COLLIN',
#   'zip code': '75070'},
#  {'name': 'NGUYEN, LOAN HONG ANH',
#   'description': "Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to disinfect the salon's whirlpool foot spa basins with an EPA-registered disinfectant after each client.",
#   'complaint number': 'COS20180016630',
#   'license number': '757086',
#   'city': 'ARLINGTON',
#   'county': 'TARRANT',
#   'zip code': '76002'},
#  {'name': 'NGUYEN, MAI THI BACH',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20190001474',
#   'license number': '725831',
#   'city': 'WILMER',
#   'county': 'DALLAS',
#   'zip code': '75172'},
#  {'name': 'NGUYEN, TUYET-MAI PHAM',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20180008796',
#   'license number': '786753',
#   'city': 'GARLAND',
#   'county': 'DALLAS',
#   'zip code': '75044'},
#  {'name': 'NGUYEN, LIEN THI B',
#   'description': 'Respondent operated a cosmetology salon without the appropriate license; Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'complaint number': 'COS20190005104',
#   'license number': '794022',
#   'city': 'LONGVIEW',
#   'county': 'GREGG',
#   'zip code': '75601'},
#  {'name': 'NGUYEN, MAI T',
#   'description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'complaint number': 'COS20180013639',
#   'license number': '750076',
#   'city': 'AUSTIN',
#   'county': 'TRAVIS',
#   'zip code': '78735'},
#  {'name': 'NGUYEN, LIEN',
#   'description': 'Respondent failed to dispose of single use items after each use.',
#   'complaint number': 'COS20180014831',
#   'license number': '746980',
#   'city': 'AMARILLO',
#   'county': 'POTTER',
#   'zip code': '79109'},
#  {'name': 'NGUYEN, NGOC THI',
#   'description': 'Respondent failed to properly ventilate the salon to eliminate strong odors away from the public area.',
#   'complaint number': 'COS20180016402',
#   'license number': '737411, 1669514, 1140000, 1240416, 1562212',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip code': '77072'},
#  {'name': 'NGUYEN, VIET LINH',
#   'description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'complaint number': 'COS20190001279',
#   'license number': 'Not Licensed',
#   'city': 'SHERMAN',
#   'county': 'GRAYSON',
#   'zip code': '75092'},
#  {'name': 'NGUYEN, COURTNEY',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20180016048',
#   'license number': '745292',
#   'city': 'BULLARD',
#   'county': 'SMITH',
#   'zip code': '75757'},
#  {'name': 'NGUYEN, TUYEN T',
#   'description': 'Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.',
#   'complaint number': 'COS20180016674',
#   'license number': '790119, 767335, 1680828',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip code': '77086'},
#  {'name': 'NGUYEN, NHON A',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20180016648',
#   'license number': '734240',
#   'city': 'KERMIT',
#   'county': 'WINKLER',
#   'zip code': '79745'},
#  {'name': 'NGUYEN, SOPHIE T',
#   'description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'complaint number': 'COS20180015386',
#   'license number': '774072',
#   'city': 'EL PASO',
#   'county': 'EL PASO',
#   'zip code': '79912'},
#  {'name': 'NGUYEN, NGOC HONG THI',
#   'description': 'Respondent failed to properly disinfect implements at the end of each day.',
#   'complaint number': 'COS20180016256',
#   'license number': '725673',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip code': '77090'},
#  {'name': 'NGUYEN, KHAN THI',
#   'description': 'Respondent failed to clean and disinfect all wax pots; Respondent failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone.',
#   'complaint number': 'COS20180003200',
#   'license number': '778045, 1290177',
#   'city': 'BRENHAM',
#   'county': 'WASHINGTON',
#   'zip code': '77833'},
#  {'name': 'NGUYEN, ANNA AI',
#   'description': 'Respondent failed to clean and disinfect all wax pots.',
#   'complaint number': 'COS20180011116',
#   'license number': '776928, 1475816',
#   'city': 'PLANO',
#   'county': 'COLLIN',
#   'zip code': '75024'},
#  {'name': 'NGUYEN, NHU MAI',
#   'description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.',
#   'complaint number': 'COS20180016602',
#   'license number': '745586',
#   'city': 'PLANO',
#   'county': 'COLLIN',
#   'zip code': '75024'},
#  {'name': 'NGUYEN, DUNG QUANG',
#   'description': 'Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20190001103',
#   'license number': '749917, 1165768',
#   'city': 'DALLAS',
#   'county': 'DALLAS',
#   'zip code': '75206'},
#  {'name': 'NGUYEN, MINH THU',
#   'description': 'Respondent was in possession of bottles containing methyl methacrylate monomer.',
#   'complaint number': 'COS20190001603',
#   'license number': '790174',
#   'city': 'EL PASO',
#   'county': 'EL PASO',
#   'zip code': '79934'},
#  {'name': 'NGUYEN, PHUONG THI',
#   'description': "Respondent failed to clean and disinfect facial chairs and beds, including headrest, prior to providing service to each client; Respondent failed to sweep up and deposit hair cuttings in a closed receptacle after each hair cut. Respondent failed to thoroughly clean the floors each day; Respondent failed to dispose of after each use all products and single use items that has been in contact with a client's skin.",
#   'complaint number': 'COS20180015604',
#   'license number': '772550',
#   'city': 'SUGAR LAND',
#   'county': 'FORT BEND',
#   'zip code': '77478'},
#  {'name': 'NGUYEN, CHARLIE',
#   'description': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the manufacturer's instructions; Respondent failed to clean and disinfect all wax pots.",
#   'complaint number': 'COS20190000020',
#   'license number': '763659',
#   'city': 'DALLAS',
#   'county': 'DALLAS',
#   'zip code': '75219'},
#  {'name': 'NGUYEN, HANH THI',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20180014868',
#   'license number': '761658',
#   'city': 'DALLAS',
#   'county': 'DALLAS',
#   'zip code': '75237'},
#  {'name': 'NGUYEN, MINH V',
#   'description': 'Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product.',
#   'complaint number': 'COS20180010801',
#   'license number': '745051',
#   'city': 'HORIZON CITY',
#   'county': 'EL PASO',
#   'zip code': '79928'},
#  {'name': 'NGUYEN, NHAN THANH',
#   'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.",
#   'complaint number': 'COS20180011570',
#   'license number': '1265637',
#   'city': 'GARLAND',
#   'county': 'DALLAS',
#   'zip code': '75040'},
#  {'name': 'NGUYEN, THUYET',
#   'description': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.',
#   'complaint number': 'COS20180009490',
#   'license number': '720045',
#   'city': 'SAN ANTONIO',
#   'county': 'BEXAR',
#   'zip code': '78251'},
#  {'name': 'NGUYEN, QUANG XUAN',
#   'description': 'Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to properly disinfect implements at the end of each day.',
#   'complaint number': 'COS20180014099',
#   'license number': '738063, 1231599',
#   'city': 'BALCH SPRINGS',
#   'county': 'DALLAS',
#   'zip code': '75180'},
#  {'name': 'NGUYEN, TRUNG N',
#   'description': 'Respondent failed to dispose of single use items after each use.',
#   'complaint number': 'COS20180007186',
#   'license number': '767014, 1196244',
#   'city': 'AMARILLO',
#   'county': 'POTTER',
#   'zip code': '79106'},
#  {'name': 'NGUYEN, MYCAM THI',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20180011017',
#   'license number': '734788',
#   'city': 'GARLAND',
#   'county': 'DALLAS',
#   'zip code': '75043'},
#  {'name': 'NGUYEN, THUYVI T',
#   'description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'complaint number': 'COS20180014315',
#   'license number': '784702',
#   'city': 'PFLUGERVILLE',
#   'county': 'TRAVIS',
#   'zip code': '78660'},
#  {'name': 'NGUYEN, OANH PHUONG',
#   'description': 'Respondent was in possession of bottles containing methyl methacrylate monomer.',
#   'complaint number': 'COS20180015729',
#   'license number': '739546',
#   'city': 'KILLEEN',
#   'county': 'BELL',
#   'zip code': '76542'},
#  {'name': 'NGUYEN, QUANG Q',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'complaint number': 'COS20180012060',
#   'license number': '771954',
#   'city': 'SANTA TERESA',
#   'county': 'OUT OF STATE',
#   'zip code': '88008'},
#  {'name': 'NGUYEN, CINDY',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to ensure that only semi-permanent glue was used during eyelash extension services.',
#   'complaint number': 'COS20180014267',
#   'license number': '786409',
#   'city': 'CORPUS CHRISTI',
#   'county': 'NUECES',
#   'zip code': '78414'},
#  {'name': 'NGUYEN, KEVIN HOA',
#   'description': "Respondent failed to disinfect the salon's whirlpool foot spa basins with an EPA-registered disinfectant after each client.",
#   'complaint number': 'COS20180012949',
#   'license number': '746655',
#   'city': 'ROSEMEAD',
#   'county': 'OUT OF STATE',
#   'zip code': '91770'},
#  {'name': 'NGUYEN, THUY T',
#   'description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'complaint number': 'COS20180014222',
#   'license number': '720854',
#   'city': 'BANDERA',
#   'county': 'BANDERA',
#   'zip code': '78003'},
#  {'name': 'NGUYEN, THIENTRANG THI',
#   'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer.',
#   'complaint number': 'COS20180010556',
#   'license number': '783069, 1655219',
#   'city': 'AUSTIN',
#   'county': 'TRAVIS',
#   'zip code': '78735'},
#  {'name': 'NGUYEN, MARY ANN',
#   'description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'complaint number': 'COS20180014330',
#   'license number': 'Not Licensed',
#   'city': 'PFLUGERVILLE',
#   'county': 'TRAVIS',
#   'zip code': '78660'},
#  {'name': 'NGUYEN, CHRISTINA M',
#   'description': 'Respondent leased space in a barber shop to an individual who engaged in the practice of barbering but had not obtained a barber license.',
#   'complaint number': 'BAR20180008307',
#   'license number': '772915, 1522245',
#   'city': 'MIDLAND',
#   'county': 'MIDLAND',
#   'zip code': '79707'},
#  {'name': 'NGUYEN, THANH CHUONG',
#   'description': 'Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.',
#   'complaint number': 'COS20180007909',
#   'license number': '748957, 1340920',
#   'city': 'SACHSE',
#   'county': 'COLLIN',
#   'zip code': '75048'},
#  {'name': 'NGUYEN, PHUONG N',
#   'description': 'Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.',
#   'complaint number': 'COS20180008524',
#   'license number': '1199884, 1706073',
#   'city': 'SEALY',
#   'county': 'AUSTIN',
#   'zip code': '77474'},
#  {'name': 'NGUYEN, ANH TRAM',
#   'description': 'Respondent failed to dispose of single use items after each use.',
#   'complaint number': 'COS20180011108',
#   'license number': '759616, 1475221, 1521294',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip code': '77089'},
#  {'name': 'NGUYEN, HIEN',
#   'description': 'Respondent performed or attempted to perform a practice of cosmetology without a license.',
#   'complaint number': 'COS20180013126',
#   'license number': 'Not Licensed',
#   'city': 'BASTROP',
#   'county': 'BASTROP',
#   'zip code': '78602'},
#  {'name': 'NGUYEN, TUAN A',
#   'description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.',
#   'complaint number': 'COS20180008708',
#   'license number': '681274',
#   'city': 'AUSTIN',
#   'county': 'TRAVIS',
#   'zip code': '78723'},
#  {'name': 'NGUYEN, LEON A',
#   'description': "Respondent submitted a renewal application that made false statements regarding the Respondent's criminal history; Respondent has been convicted of a crime that was committed within 5 years of their renewal application; Respondent lacks sufficient honesty, trustworthiness and integrity to hold a license.",
#   'complaint number': 'COS20180008891',
#   'license number': '1173346',
#   'city': 'SACHSE',
#   'county': 'COLLIN',
#   'zip code': '75048'},
#  {'name': 'NGUYEN, VINH QUANG',
#   'description': 'Respondent was in possession of bottles containing methyl methacrylate monomer.',
#   'complaint number': 'COS20180012418',
#   'license number': '712441',
#   'city': 'EL PASO',
#   'county': 'EL PASO',
#   'zip code': '79901'},
#  {'name': 'NGUYEN, BINH VAN',
#   'description': 'Respondent was in possession of bottles containing methyl methacrylate monomer.',
#   'complaint number': 'COS20180015790',
#   'license number': '756644',
#   'city': 'KILLEEN',
#   'county': 'BELL',
#   'zip code': '76543'},
#  {'name': 'NGUYEN, SHARON',
#   'description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.',
#   'complaint number': 'COS20180013118',
#   'license number': '750030',
#   'city': 'BASTROP',
#   'county': 'BASTROP',
#   'zip code': '78602'},
#  {'name': 'NGUYEN, BINH THANH',
#   'description': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection.',
#   'complaint number': 'COS20180012368',
#   'license number': '772744',
#   'city': 'LAREDO',
#   'county': 'WEBB',
#   'zip code': '78045'},
#  {'name': 'NGUYEN, DU HUU',
#   'description': 'Respondent operated a massage establishment without a license.',
#   'complaint number': 'MAS20180006447',
#   'license number': '749746, 1410150',
#   'city': 'ARLINGTON',
#   'county': 'TARRANT',
#   'zip code': '76014'},
#  {'name': 'NGUYEN, SAMANTHA TRAN',
#   'description': 'Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.',
#   'complaint number': 'COS20180006595',
#   'license number': '743492, 1279657, 1562243',
#   'city': 'MCKINNEY',
#   'county': 'COLLIN',
#   'zip code': '75070'},
#  {'name': 'NGUYEN, THU LE',
#   'description': 'Respondent failed to comply with an order previously issued by the Executive Director.',
#   'complaint number': 'COS20180007798',
#   'license number': '11224436, 685119',
#   'city': 'SAN ANTONIO',
#   'county': 'BEXAR',
#   'zip code': '78216'},
#  {'name': 'NGUYEN, KIM NGAN THI',
#   'description': 'Respondent interfered with a Department inspection of the salon.',
#   'complaint number': 'COS2009004238D',
#   'license number': '1434311',
#   'city': 'HOUSTON',
#   'county': 'HARRIS',
#   'zip code': '77084'}]

# %% [markdown]
# ### Save that to a CSV
#
# - Tip: Use `pd.DataFrame` to create a dataframe, and then save it to a CSV.

# %%
import pandas as pd
df = pd.DataFrame(eachdict)
df.to_csv("Texas Cosmetology Violations.csv",sep=',',index=False)
df
# Out:
# /Users/paromasoni/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
#                         name  \
# 0          NGUYEN, MIMI PHAM
# 1                 NGUYEN, HA
# 2          NGUYEN, THAO HONG
# 3              NGUYEN, CINDY
# 4    NGUYEN, CHAU KHANH LINH
# ..                       ...
# 159       NGUYEN, BINH THANH
# 160           NGUYEN, DU HUU
# 161    NGUYEN, SAMANTHA TRAN
# 162           NGUYEN, THU LE
# 163     NGUYEN, KIM NGAN THI
#
#                                            description complaint number  \
# 0    Respondent failed properly clean and sanitize ...   COS20190010072
# 1    Respondent failed to clean and sanitize four (...   COS20190016762
# 2    Respondent failed to clean, disinfect, and ste...   COS20200010387
# 3    Respondent failed to clean and disinfect all w...   COS20200010502
# 4    Respondent engaged in fraud or deceit in obtai...   COS20190008104
# ..                                                 ...              ...
# 159  Respondent leased space in a salon to an indiv...   COS20180012368
# 160  Respondent operated a massage establishment wi...   MAS20180006447
# 161  Respondent failed to clean, disinfect, and ste...   COS20180006595
# 162  Respondent failed to comply with an order prev...   COS20180007798
# 163  Respondent interfered with a Department inspec...   COS2009004238D
#
#                license number            city        county zip code
# 0                      784210            KATY        HARRIS    77449
# 1                      764888       ARLINGTON       TARRANT    76017
# 2             799926, 1753491     SAN ANTONIO         BEXAR    78238
# 3    806232, 1260359, 1280071  CORPUS CHRISTI        NUECES    78414
# 4                     1764073      MONTGOMERY  OUT OF STATE    36116
# ..                        ...             ...           ...      ...
# 159                    772744          LAREDO          WEBB    78045
# 160           749746, 1410150       ARLINGTON       TARRANT    76014
# 161  743492, 1279657, 1562243        MCKINNEY        COLLIN    75070
# 162          11224436, 685119     SAN ANTONIO         BEXAR    78216
# 163                   1434311         HOUSTON        HARRIS    77084
#
# [164 rows x 7 columns]

# %% [markdown]
# ### Open the CSV file and examine the first few. Make sure you didn't save an extra weird unnamed column.

# %%
df2 = pd.read_csv("Texas Cosmetology Violations.csv")
df2.head()
# Out:
#                       name                                        description  \
# 0        NGUYEN, MIMI PHAM  Respondent failed properly clean and sanitize ...
# 1               NGUYEN, HA  Respondent failed to clean and sanitize four (...
# 2        NGUYEN, THAO HONG  Respondent failed to clean, disinfect, and ste...
# 3            NGUYEN, CINDY  Respondent failed to clean and disinfect all w...
# 4  NGUYEN, CHAU KHANH LINH  Respondent engaged in fraud or deceit in obtai...
#
#   complaint number            license number            city        county  \
# 0   COS20190010072                    784210            KATY        HARRIS
# 1   COS20190016762                    764888       ARLINGTON       TARRANT
# 2   COS20200010387           799926, 1753491     SAN ANTONIO         BEXAR
# 3   COS20200010502  806232, 1260359, 1280071  CORPUS CHRISTI        NUECES
# 4   COS20190008104                   1764073      MONTGOMERY  OUT OF STATE
#
#    zip code
# 0     77449
# 1     76017
# 2     78238
# 3     78414
# 4     36116

# %% [markdown]
# ## Let's do this an easier way
#
# Use Selenium and `pd.read_html` to get the table as a dataframe.

# %%
df3 = pd.read_html(driver.page_source)
df3 = df3[0]
df3

#This is not a proper table but leaving it as is anyway? Do we need to use regex to extract the different columns?
# Out:
#                                      Name and Location  \
# 0    NGUYEN, MIMI PHAM City: KATY County: HARRIS Zi...
# 1    NGUYEN, HA City: ARLINGTON County: TARRANT Zip...
# 2    NGUYEN, THAO HONG City: SAN ANTONIO County: BE...
# 3    NGUYEN, CINDY City: CORPUS CHRISTI County: NUE...
# 4    NGUYEN, CHAU KHANH LINH City: MONTGOMERY Count...
# ..                                                 ...
# 159  NGUYEN, BINH THANH City: LAREDO County: WEBB Z...
# 160  NGUYEN, DU HUU City: ARLINGTON County: TARRANT...
# 161  NGUYEN, SAMANTHA TRAN City: MCKINNEY County: C...
# 162  NGUYEN, THU LE City: SAN ANTONIO County: BEXAR...
# 163  NGUYEN, KIM NGAN THI City: HOUSTON County: HAR...
#
#                                                  Order  \
# 0    Date: 11/12/2020Respondent is assessed an admi...
# 1    Date: 11/12/2020Respondent is assessed an admi...
# 2    Date: 11/12/2020Respondent is assessed an admi...
# 3    Date: 10/29/2020Respondent is assessed an admi...
# 4    Date: 10/26/2020The Respondent's Cosmetology M...
# ..                                                 ...
# 159  Date: 9/12/2018Respondent is assessed an admin...
# 160  Date: 9/12/2018Respondent is assessed an admin...
# 161  Date: 9/4/2018Respondent is assessed an admini...
# 162  Date: 8/7/2018The Respondent's Cosmetology Man...
# 163  Date: 12/9/2009Respondent is assessed an admin...
#
#                                        Basis for Order
# 0    Respondent failed properly clean and sanitize ...
# 1    Respondent failed to clean and sanitize four (...
# 2    Respondent failed to clean, disinfect, and ste...
# 3    Respondent failed to clean and disinfect all w...
# 4    Respondent engaged in fraud or deceit in obtai...
# ..                                                 ...
# 159  Respondent leased space in a salon to an indiv...
# 160  Respondent operated a massage establishment wi...
# 161  Respondent failed to clean, disinfect, and ste...
# 162  Respondent failed to comply with an order prev...
# 163  Respondent interfered with a Department inspec...
#
# [164 rows x 3 columns]
